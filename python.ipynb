# %% [markdown]
# <a href="https://colab.research.google.com/github/shauryaraj9/PBEL/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Introduction</h1>
# <h3>Python was created by Guido van Rossum in 1991 and further developed by the Python Software Foundation. It was designed with focus on code readability and its syntax allows us to express concepts in fewer lines of code.</h3>
#
# - Key Features of Python
# Python’s simple and readable syntax makes it beginner-friendly.
# Python runs seamlessly on Windows, macOS and Linux.
# Includes libraries for tasks like web development, data analysis and machine learning.
# Variable types are determined automatically at runtime, simplifying code writing.
# Supports multiple programming paradigms, including object-oriented, functional and procedural programming.
# Python is free to use, distribute and modify.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#print
print(123)
# Out:
# 123

# %%
a="45.5"
type(a)
print(a, "a is a number",a)
# Out:
# 45.5 a is a number 45.5

# %%
for x in range(0,10,2):
 print(x)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
a=1 #int
b=2.1 #float
c=

# %%
name='hello'
#name.capitalize()
#name.count("l")
name[0:4]
# Out:
# 'hell'

# %%
#List
list1=[]
type(list1)
# Out:
# list

# %%
list1=[1,2,3,"s","ram",True,2.5,1,2]
print(list1)
# Out:
# [1, 2, 3, 's', 'ram', True, 2.5, 1, 2]

# %%
list1[0]=5
print(list1)
list1.pop(1)
print(list1)
# Out:
# [5, 3, 's', 'ram', True, 2.5, 1, 2]
# [5, 's', 'ram', True, 2.5, 1, 2]

# %%
tuple1=(1,2,3,"s",True,2.5)
print(tuple1)
# Out:
# (1, 2, 3, 's', True, 2.5)

# %%
tuple1.count(1)
# Out:
# 2

# %%
#function
def HBTY(name):
  print("Happy birthday to you",name)

# %%
HBTY(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-3694750344.py in <cell line: 0>()
# ----> 1 HBTY(name)
#
# NameError: name 'HBTY' is not defined

# %%
#control flo

# %%
import pandas as pd
dict1={"name":["moham","raci","keshav"], "age":[20,23,45]}
Data=pd.DataFrame(dict1)
# Out:
#      name  age
# 0   moham   20
# 1    raci   23
# 2  keshav   45

# %%
a=input()
if a =="hungary" :
  print("yes")
elif a == "not_hungary":
  print("no")
else:
  print("default case")
# Out:
# nno
# default case
